# %%
import pandas as pd
import datetime
import numpy as np

# %%
# loading customer data
df_customer = pd.read_csv("C:\\Users\\haris\\Downloads\\Customers.csv", encoding='latin1')

# %%
df_customer.shape # Display the shape of the data frame
# Out:
# (15266, 10)

# %%
df_customer.head() # first 5 rows
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia    7/3/1939
# 1  Western Australia     6522  Australia  Australia   9/27/1979
# 2           Victoria     3380  Australia  Australia   5/26/1947
# 3    South Australia     5223  Australia  Australia   9/17/1957
# 4           Victoria     3698  Australia  Australia  11/19/1965

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
df_customer.isnull().sum() #checking for missing values
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
#Accessing null value entries in state code
df_customer[df_customer["State Code"].isnull()]
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# ...

# %%
#Accessing any other entries with State Napoli
df_customer[df_customer["State"] == "Napoli"]
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# ...

# %%
df_customer["State Code"].fillna("NA", inplace=True) # Filling missing values with NA

# %%
df_customer.isnull().sum() #checking for missing values
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
print(df_customer.duplicated().sum()) # Checking for duplicates
# Out:
# 0

# %%
# Changing the birthday column to yyyy-mm-dd format
df_customer["Birthday"] = pd.to_datetime(df_customer["Birthday"], format='mixed', dayfirst=True).dt.strftime('%Y-%m-%d')

# %%
df_customer.head() #First 5 row after changing the format of birthday
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia  1939-03-07
# 1  Western Australia     6522  Australia  Australia  1979-09-27
# 2           Victoria     3380  Australia  Australia  1947-05-26
# 3    South Australia     5223  Australia  Australia  1957-09-17
# 4           Victoria     3698  Australia  Australia  1965-11-19

# %%
# Saving the cleaned data to a new csv file
df_customer.to_csv("C:\\Users\\haris\\Downloads\\Customers_cleaned.csv", index=False)

# %%
#loading exchange rates
df_exchange=pd.read_csv("C:\\Users\\haris\\Downloads\\Exchange_Rates.csv",encoding='latin-1')

# %%
df_exchange.head() #First 5 rows
# Out:
#        Date Currency  Exchange
# 0  1/1/2015      USD    1.0000
# 1  1/1/2015      CAD    1.1583
# 2  1/1/2015      AUD    1.2214
# 3  1/1/2015      EUR    0.8237
# 4  1/1/2015      GBP    0.6415

# %%
df_exchange .shape # Display the shape of the data frame
# Out:
# (11215, 3)

# %%
df_exchange.info() #Display the information of the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
df_exchange.isnull().sum() # Null values in the data frame
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
# Convert the 'Date' column to datetime format and ensure it's in 'YYYY-MM-DD' format for SQL
df_exchange['Date'] = pd.to_datetime(df_exchange['Date'], format='mixed').dt.strftime('%Y-%m-%d')
# Check the first few rows to verify the conversion
print(df_exchange.head())
# Out:
#          Date Currency  Exchange
# 0  2015-01-01      USD    1.0000
# 1  2015-01-01      CAD    1.1583
# 2  2015-01-01      AUD    1.2214
# 3  2015-01-01      EUR    0.8237
# 4  2015-01-01      GBP    0.6415

# %%
print(df_exchange.duplicated().sum()) # Checking for duplicates
# Out:
# 0

# %%
# Saving the cleaned csv file
df_exchange.to_csv("C:\\Users\\haris\\Downloads\\Exchange_rates_cleaned.csv", index=False)

# %%
#Loading product files
df_products=pd.read_csv("C:\\Users\\haris\\Downloads\\Products.csv",encoding ="latin-1")

# %%
df_products.shape
# Out:
# (2517, 10)

# %%
df_products.head() #First 5 rows of the data frame
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
df_products.isnull().sum() # displays null values
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
print(df_products.duplicated().sum()) # Checking for duplicates
# Out:
# 0

# %%
#  Replacing dollar sign and commas, then converting to float
df_products['Unit Cost USD'] = df_products['Unit Cost USD'].astype(str).str.replace('$', '').str.replace(',', '').astype(float)
df_products['Unit Price USD'] = df_products['Unit Price USD'].astype(str).str.replace('$', '').str.replace(',', '').astype(float)

df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
df_products.head() #Checking the first 5 rows after cleaning
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#    Unit Cost USD  Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0           6.62           12.99             101     MP4&MP3            1
# 1           6.62           12.99             101     MP4&MP3            1
# 2           7.40           14.52             101     MP4&MP3            1
# 3          11.00           21.57             101     MP4&MP3            1
# 4          11.00           21.57             101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
#Saving the cleaned csv File
df_products.to_csv("C:\\Users\\haris\\Downloads\\Products_cleaned.csv", index=False)

# %%
#Loading the sales csv file
df_sales=pd.read_csv("C:\\Users\\haris\\Downloads\\Sales.csv",encoding = 'latin-1')

# %%
df_sales.head() #First 5 rows of the data frame
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
df_sales.shape
# Out:
# (62884, 9)

# %%
df_sales.info() # information about the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
df_sales.isnull().sum() # Checking for null values
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
#Dropping delivery date column
df_sales.drop("Delivery Date",axis=1,inplace=True)
df_sales.head() #checking the first 5 rows after removing the column
# Out:
#    Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0        366000          1   1/1/2016       265598        10        1304
# 1        366001          1   1/1/2016      1269051         0        1048
# 2        366001          2   1/1/2016      1269051         0        2007
# 3        366002          1   1/1/2016       266019         0        1106
# 4        366002          2   1/1/2016       266019         0         373
#
#    Quantity Currency Code
# 0         1           CAD
# 1         2           USD
# 2         1           USD
# 3         7           CAD
# 4         1           CAD

# %%
df_sales.isnull().sum() # Checking for missing values after cleaning
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
print(df_sales.duplicated().sum()) #Checking for duplicates
# Out:
# 0

# %%
# changing order date to correct format yyyy-mm-dd
df_sales['Order Date'] = pd.to_datetime(df_sales['Order Date'], format='mixed', dayfirst=True)
df_sales["Order Date"] = df_sales['Order Date'].dt.strftime('%Y-%m-%d')
df_sales.head() #Checking the first 5 rows after cleaning
# Out:
#    Order Number  Line Item  Order Date  CustomerKey  StoreKey  ProductKey  \
# 0        366000          1  2016-01-01       265598        10        1304
# 1        366001          1  2016-01-01      1269051         0        1048
# 2        366001          2  2016-01-01      1269051         0        2007
# 3        366002          1  2016-01-01       266019         0        1106
# 4        366002          2  2016-01-01       266019         0         373
#
#    Quantity Currency Code
# 0         1           CAD
# 1         2           USD
# 2         1           USD
# 3         7           CAD
# 4         1           CAD

# %%
#Saving the cleaned csv file
df_sales.to_csv("C:\\Users\\haris\\Downloads\\Sales_cleaned.csv", index=False)

# %%
# Loading Stores file
df_stores=pd.read_csv("C:\\Users\\haris\\Downloads\\Stores.csv",encoding='latin-1')

# %%
df_stores.head()
# Out:
#    StoreKey    Country                         State  Square Meters  Open Date
# 0         1  Australia  Australian Capital Territory          595.0   1/1/2008
# 1         2  Australia            Northern Territory          665.0  1/12/2008
# 2         3  Australia               South Australia         2000.0   1/7/2012
# 3         4  Australia                      Tasmania         2000.0   1/1/2010
# 4         5  Australia                      Victoria         2000.0  12/9/2015

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df_stores.isnull().sum() # Checking for missing values
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
df_stores.dropna(inplace=True) # Dropping missing values
df_stores.isnull().sum() # Checking for missing values
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
print(df_stores.duplicated().sum()) # Checking for duplicates
# Out:
# 0

# %%
#Changing open date to yyyy-mm-dd format
df_stores['Open Date'] = pd.to_datetime(df_stores['Open Date'], format='mixed', dayfirst=True)
df_stores["Open Date"] = df_stores['Open Date'].dt.strftime('%Y-%m-%d')
df_stores.head()
# Out:
#    StoreKey    Country                         State  Square Meters  \
# 0         1  Australia  Australian Capital Territory          595.0
# 1         2  Australia            Northern Territory          665.0
# 2         3  Australia               South Australia         2000.0
# 3         4  Australia                      Tasmania         2000.0
# 4         5  Australia                      Victoria         2000.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-12-01
# 2  2012-07-01
# 3  2010-01-01
# 4  2015-09-12

# %%
#Saving the cleaned csv file
df_stores.to_csv("C:\\Users\\haris\\Downloads\\Stores_cleaned.csv",index=False)

# %%
# Merging customer and sales data frame
df_customer_sales = pd.merge(df_customer, df_sales, on='CustomerKey', how='inner')

# %%
df_customer_sales.head() #First 5 rows of the merged data frame
# Out:
#    CustomerKey  Gender           Name            City State Code  \
# 0          301  Female  Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female   Madison Hull      MOUNT BUDD         WA
# 2          325  Female   Madison Hull      MOUNT BUDD         WA
# 3          325  Female   Madison Hull      MOUNT BUDD         WA
# 4          325  Female   Madison Hull      MOUNT BUDD         WA
#
#                State Zip Code    Country  Continent    Birthday  Order Number  \
# 0    South Australia     5523  Australia  Australia  1939-03-07       1776007
# 1  Western Australia     6522  Australia  Australia  1979-09-27       1109001
# 2  Western Australia     6522  Australia  Australia  1979-09-27       1109001
# 3  Western Australia     6522  Australia  Australia  1979-09-27       1109001
# 4  Western Australia     6522  Australia  Australia  1979-09-27       1781006
#
#    Line Item  Order Date  StoreKey  ProductKey  Quantity Currency Code
# ...

# %%
#saving the merged data frame to csv
df_customer_sales.to_csv("C:\\Users\\haris\\Downloads\\Customer_Sales.csv",index=False)

# %%
#merging the customer_sales and products data frame
df_customer_sales_products = pd.merge(df_customer_sales, df_products, on='ProductKey', how='inner')
df_customer_sales_products.head() #First 5 rows of the merged data frame
# Out:
#    CustomerKey  Gender           Name            City State Code  \
# 0          301  Female  Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female   Madison Hull      MOUNT BUDD         WA
# 2          325  Female   Madison Hull      MOUNT BUDD         WA
# 3          325  Female   Madison Hull      MOUNT BUDD         WA
# 4          325  Female   Madison Hull      MOUNT BUDD         WA
#
#                State Zip Code    Country  Continent    Birthday  ...  \
# 0    South Australia     5523  Australia  Australia  1939-03-07  ...
# 1  Western Australia     6522  Australia  Australia  1979-09-27  ...
# 2  Western Australia     6522  Australia  Australia  1979-09-27  ...
# 3  Western Australia     6522  Australia  Australia  1979-09-27  ...
# 4  Western Australia     6522  Australia  Australia  1979-09-27  ...
#
#    Currency Code                                       Product Name  \
# 0            AUD             WWI 4GB Video Recording Pen X200 Black
# ...

# %%
#saving the merged data frame to csv
df_customer_sales_products.to_csv("C:\\Users\\haris\\Downloads\\Customer_Sales_Products.csv",index=False)

# %%
#Merging products and sales data frame
df_products_sales = pd.merge(df_products, df_sales, on='ProductKey', how='inner')
df_products_sales.head() #First 5 rows of the merged data frame
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 2           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 3           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 4           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
#
#    Unit Cost USD  Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0           6.62           12.99             101     MP4&MP3            1
# 1           6.62           12.99             101     MP4&MP3            1
# 2           6.62           12.99             101     MP4&MP3            1
# 3           6.62           12.99             101     MP4&MP3            1
# 4           6.62           12.99             101     MP4&MP3            1
#
#   Category  Order Number  Line Item  Order Date  CustomerKey  StoreKey  \
# ...

# %%
#saving the merged data frame to csv
df_products_sales.to_csv("C:\\Users\\haris\\Downloads\\Products_Sales.csv",index=False)

# %%
#Merging the data frame with stores
df_customer_sales_products_stores = pd.merge(df_customer_sales_products, df_stores, on='StoreKey', how='inner')
df_customer_sales_products_stores.head() #First 5 rows of the merged data frame
# Out:
#    CustomerKey  Gender          Name        City State Code  \
# 0          325  Female  Madison Hull  MOUNT BUDD         WA
# 1          325  Female  Madison Hull  MOUNT BUDD         WA
# 2          325  Female  Madison Hull  MOUNT BUDD         WA
# 3          325  Female  Madison Hull  MOUNT BUDD         WA
# 4          325  Female  Madison Hull  MOUNT BUDD         WA
#
#              State_x Zip Code  Country_x  Continent    Birthday  ...  \
# 0  Western Australia     6522  Australia  Australia  1979-09-27  ...
# 1  Western Australia     6522  Australia  Australia  1979-09-27  ...
# 2  Western Australia     6522  Australia  Australia  1979-09-27  ...
# 3  Western Australia     6522  Australia  Australia  1979-09-27  ...
# 4  Western Australia     6522  Australia  Australia  1979-09-27  ...
#
#    Unit Cost USD  Unit Price USD SubcategoryKey               Subcategory  \
# 0         160.49          349.00            303                  Desktops
# ...

# %%
#saving the merged data frame to csv
df_customer_sales_products_stores.to_csv("C:\\Users\\haris\\Downloads\\Customer_Sales_Products_Stores.csv",index=False)
